# %%
import pandas as pd

df=pd.read_parquet('transactions.parquet')

df.to_csv('data.csv')
# Out:
# C:\Users\jyoti\AppData\Local\Temp\ipykernel_15740\884361310.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df['BrandName'] = df['BrandName'].astype('category')
df['ModelGroup'] = df['ModelGroup'].astype('category')
df['ProductGroup'] = df['ProductGroup'].astype('category')

# %%
# Get unique numerical values in each column
unique_brand_names = df['BrandName'].unique()
unique_model_groups = df['ModelGroup'].unique()
unique_product_groups = df['ProductGroup'].unique()

# Print unique values
print("Unique numerical values in BrandName:", unique_brand_names)
print("Unique numerical values in ModelGroup:", unique_model_groups)
print("Unique numerical values in ProductGroup:", unique_product_groups)
# Out:
# Unique numerical values in BrandName: [3694837121284491212, -1657270726128381662, -7202472198306336051, -2074012670196538378, -4869459690934553786, ..., 7517016695256219568, -6988743831713857166, 2422118029599885529, -872797489046909906, -7244046429025905887]
# Length: 649
# Categories (649, int64): [-9188398371112724402, -9154070123208926236, -9121749129799555055, -9111042495772325286, ..., 9074369711721722972, 9099678989100129917, 9178759879362980169, 9213972401055508159]
# Unique numerical values in ModelGroup: [3162564956579801398, -6715310361529623819, -248459121805647149, -4124706989267335995, -837118628879098305, ..., 2552887355222480171, -1985744308537605242, -2724180456806002628, -3872800907285994177, -6534481151174441087]
# Length: 32
# Categories (32, int64): [-8581610949319170507, -7693559481885520974, -6715310361529623819, -6534481151174441087, ..., 6450924088821678307, 6742804956075612187, 7383880531496163867, 8676381074854750838]
# ...

# %%
# Get unique numerical values with frequencies in each column
brand_name_counts = df['BrandName'].value_counts()
model_group_counts = df['ModelGroup'].value_counts()
product_group_counts = df['ProductGroup'].value_counts()

# Print unique values with frequencies
print("Unique numerical values in BrandName with frequencies:\n", brand_name_counts)
print("Unique numerical values in ModelGroup with frequencies:\n", model_group_counts)
print("Unique numerical values in ProductGroup with frequencies:\n", product_group_counts)
# Out:
# Unique numerical values in BrandName with frequencies:
#  BrandName
# -1671135878886367730    110208
# -4445228402666777776    101136
#  3694837121284491212     94397
# -8892132782483441489     89876
#  2163194981545980604     71682
#                          ...
# -632115612641285033          1
# -872797489046909906          1
# -2041464652498643948         1
# -1249912174650901421         1
#  2422118029599885529         1
# Name: count, Length: 649, dtype: int64
# Unique numerical values in ModelGroup with frequencies:
#  ModelGroup
# -4124706989267335995    703042
#  3162564956579801398    564852
# -248459121805647149      71818
#  6742804956075612187     69802
# -6715310361529623819     64497
# -2426224035638420213     56925
# -1330987452709117740     38580
#  8676381074854750838     34771
# -2375149457939821456     21986
# -1172740817228586022     20188
#  6450924088821678307     20129
# -965590225519141271      14728
# -713617190452378892      12027
# ...

# %%
# Get unique numerical values in the ProductGroup column
unique_product_groups = df['ProductGroup'].unique()

# Define a mapping dictionary to map numerical values to categories
mapping_dict = {}
for idx, value in enumerate(unique_product_groups):
    mapping_dict[value] = chr(ord('A') + idx)  # Mapping numerical values to letters A, B, C, ...

# Map numerical values to categories using the mapping dictionary
df['ProductGroup'] = df['ProductGroup'].map(mapping_dict)

# Save the DataFrame back to the CSV file
df.to_csv("your_dataset.csv", index=False)

# %%
# Get unique numerical values in the BrandName and ModelGroup columns
unique_brand_names = df['BrandName'].unique()
unique_model_groups = df['ModelGroup'].unique()

# Define a mapping dictionary to map numerical values to categories
mapping_dict_brand = {}
for idx, value in enumerate(unique_brand_names):
    mapping_dict_brand[value] = f"Brand_{idx + 1}"  # Mapping numerical values to categories like Brand_1, Brand_2, ...

mapping_dict_model = {}
for idx, value in enumerate(unique_model_groups):
    mapping_dict_model[value] = f"Model_{idx + 1}"  # Mapping numerical values to categories like Model_1, Model_2, ...

# Map numerical values to categories using the mapping dictionary
df['BrandName'] = df['BrandName'].map(mapping_dict_brand)
df['ModelGroup'] = df['ModelGroup'].map(mapping_dict_model)

# Save the DataFrame back to the CSV file
df.to_csv("your_dataset.csv", index=False)

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("your_dataset.csv")

# Convert the 'shops' column into two categories
df['ShopCategory'] = df['Shop'].apply(lambda x: 'Webshop' if int(x) >= 100 else 'Offline')

# Drop the original 'Shop' column if needed
# df.drop(columns=['Shop'], inplace=True)

# Save the DataFrame back to the CSV file
df.to_csv("your_dataset.csv", index=False)

# %%
print(df.head())
# Out:
#    Shop  Order_Date_FK          ProductCode  OriginalSaleAmountInclVAT  \
# 0    36       20210730 -1968361059464632550                      99.95
# 1    58       20210730 -1745497788861904687                      21.95
# 2    49       20210730 -4482110002029860032                      69.95
# 3    49       20210730 -9146072753857637799                      99.95
# 4    15       20210730 -8829485741699345914                      49.95
#
#             CustomerID  SaleDocumentNumber  Returned  RevenueInclVAT  \
# 0 -2190786785520839526            23995792         0           74.96
# 1 -3499949798555834600            23995794         0           21.95
# 2 -7841417233849937172            23995797         0           38.47
# 3 -7841417233849937172            23995797         0           54.97
# 4  7033964597104594686            23995798         0           17.48
#
#    CostPriceExclVAT BrandName ModelGroup ProductGroup ShopCategory
# ...

# %%
print(df.dtypes)
# Out:
# Shop                           int64
# Order_Date_FK                  int64
# ProductCode                    int64
# OriginalSaleAmountInclVAT    float64
# CustomerID                     int64
# SaleDocumentNumber             int64
# Returned                       int64
# RevenueInclVAT               float64
# CostPriceExclVAT             float64
# BrandName                     object
# ModelGroup                    object
# ProductGroup                  object
# ShopCategory                  object
# dtype: object

# %%
print(df.info())

# Summary statistics for numerical columns
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1759889 entries, 0 to 1759888
# Data columns (total 13 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Shop                       int64
#  1   Order_Date_FK              int64
#  2   ProductCode                int64
#  3   OriginalSaleAmountInclVAT  float64
#  4   CustomerID                 int64
#  5   SaleDocumentNumber         int64
#  6   Returned                   int64
#  7   RevenueInclVAT             float64
#  8   CostPriceExclVAT           float64
#  9   BrandName                  object
#  10  ModelGroup                 object
#  11  ProductGroup               object
#  12  ShopCategory               object
# dtypes: float64(3), int64(6), object(4)
# memory usage: 174.5+ MB
# None
#                Shop  Order_Date_FK   ProductCode  OriginalSaleAmountInclVAT  \
# count  1.759889e+06   1.759889e+06  1.759889e+06               1.759889e+06
# ...

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# Shop                         0
# Order_Date_FK                0
# ProductCode                  0
# OriginalSaleAmountInclVAT    0
# CustomerID                   0
# SaleDocumentNumber           0
# Returned                     0
# RevenueInclVAT               0
# CostPriceExclVAT             0
# BrandName                    0
# ModelGroup                   0
# ProductGroup                 0
# ShopCategory                 0
# dtype: int64

# %%
# Explore the distributions of features
# Numeric features
numeric_features = ['OriginalSaleAmountInclVAT']
# Categorical features
categorical_features = ['Shop', 'BrandName', 'ModelGroup', 'ProductGroup', 'ShopCategory', 'Returned']

# Visualize distributions of numeric features
for feature in numeric_features:
    plt.figure(figsize=(8, 5))
    sns.histplot(df[feature], kde=True)
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.show()

# Visualize distributions of categorical features
for feature in categorical_features:
    plt.figure(figsize=(10, 6))
    sns.countplot(x=feature, data=df)
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.show()

# Understand the target variable (Returned)
# Check distribution of the target variable
plt.figure(figsize=(6, 4))
sns.countplot(x='Returned', data=df)
plt.title('Distribution of Returned')
plt.xlabel('Returned')
plt.ylabel('Count')
plt.show()

# Encode categorical variables
# You can use one-hot encoding or label encoding based on the number of unique categories and the nature of the data
# For simplicity, let's use one-hot encoding for now
data_encoded = pd.get_dummies(df, columns=['ShopCategory', 'BrandName', 'ModelGroup', 'ProductGroup'], drop_first=True)

# Display the first few rows of the encoded dataset
print("First few rows of the encoded dataset:")
print(data_encoded.head())

# Explore relationships between features and the target variable through visualizations and statistical analyses
# You can use scatter plots, box plots, correlation matrices, or pair plots for visualization
# For statistical analyses, you can use correlation coefficients, chi-square tests, or ANOVA tests depending on the data type
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 9
#       7 # Visualize distributions of numeric features
#       8 for feature in numeric_features:
# ----> 9     plt.figure(figsize=(8, 5))
#      10     sns.histplot(df[feature], kde=True)
#      11     plt.title(f'Distribution of {feature}')
#
# NameError: name 'plt' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Distribution of categorical variables
plt.figure(figsize=(10, 6))
sns.countplot(x='ShopCategory', data=df)
plt.title('Distribution of Shop Category')
plt.xlabel('Shop Category')
plt.ylabel('Count')
plt.show()

# Distribution of numerical variables
plt.figure(figsize=(10, 6))
sns.histplot(df['OriginalSaleAmountInclVAT'], bins=20, kde=True)
plt.title('Distribution of Original Sale Amount (Incl VAT)')
plt.xlabel('Original Sale Amount (Incl VAT)')
plt.ylabel('Frequency')
plt.show()

# Relationship between numerical variables
plt.figure(figsize=(10, 6))
sns.scatterplot(x='OriginalSaleAmountInclVAT', y='RevenueInclVAT', data=df)
plt.title('Original Sale Amount vs. Revenue (Incl VAT)')
plt.xlabel('Original Sale Amount (Incl VAT)')
plt.ylabel('Revenue (Incl VAT)')
plt.show()

# Relationship between categorical and numerical variables
plt.figure(figsize=(10, 6))
sns.boxplot(x='ShopCategory', y='OriginalSaleAmountInclVAT', data=df)
plt.title('Shop Category vs. Original Sale Amount (Incl VAT)')
plt.xlabel('Shop Category')
plt.ylabel('Original Sale Amount (Incl VAT)')
plt.show()

# %%
# Calculate return rate by shop category
return_rate = df.groupby('ShopCategory')['Returned'].mean()
print(return_rate)
# Out:
# ShopCategory
# Offline    0.024879
# Webshop    0.185642
# Name: Returned, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x=return_rate.index, y=return_rate.values)
plt.title('Return Rate by Shop Category')
plt.xlabel('Shop Category')
plt.ylabel('Return Rate')
plt.show()

# %%
# Compare distributions of BrandName between webshops and offline shops
plt.figure(figsize=(12, 6))
sns.countplot(x='BrandName', hue='ShopCategory', data=df)
plt.title('Distribution of BrandName by Shop Category')
plt.xlabel('BrandName')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='ShopCategory', loc='upper right')
plt.tight_layout()
plt.show()

# Compare distributions of ModelGroup between webshops and offline shops
plt.figure(figsize=(14, 6))  # Adjust figure size for better readability
plt.subplot(1, 2, 2)
sns.countplot(x='ModelGroup', hue='ShopCategory', data=df)
plt.title('Distribution of ModelGroup by Shop Category')
plt.xlabel('ModelGroup')
plt.ylabel('Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.legend(title='ShopCategory', loc='upper right')
plt.tight_layout()
plt.show()
#Shipping and Delivery:
#Investigate shipping and delivery-related factors such as Order_Date_FK, SaleDocumentNumber, and OriginalSaleAmountInclVAT. Delays or discrepancies in order fulfillment and delivery processes may lead to higher return rates in webshops.

# Compare distributions of Order_Date_FK and OriginalSaleAmountInclVAT between webshops and offline shops
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(x='Order_Date_FK', hue='ShopCategory', data=df, kde=True)
plt.title('Distribution of Order Date by Shop Category')
plt.xlabel('Order Date')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='ShopCategory')

plt.subplot(1, 2, 2)
sns.histplot(x='OriginalSaleAmountInclVAT', hue='ShopCategory', data=df, kde=True)
plt.title('Distribution of Original Sale Amount by Shop Category')
plt.xlabel('Original Sale Amount (Incl VAT)')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='ShopCategory')

plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Check the DataFrame for the specified ModelGroup values
filtered_df = df[df['ModelGroup'].isin(['Model_1', 'Model_4'])]
print(filtered_df.head())
# Out:
#    Shop  Order_Date_FK          ProductCode  OriginalSaleAmountInclVAT  \
# 0    36       20210730 -1968361059464632550                      99.95
# 4    15       20210730 -8829485741699345914                      49.95
# 5    15       20210730  9221523181585526717                      59.95
# 6    15       20210730  9221523181585526717                      59.95
# 7    57       20210730 -6530540459055041583                      65.95
#
#             CustomerID  SaleDocumentNumber  Returned  RevenueInclVAT  \
# 0 -2190786785520839526            23995792         0           74.96
# 4  7033964597104594686            23995798         0           17.48
# 5  7033964597104594686            23995798         0           44.96
# 6  7033964597104594686            23995798         0           44.96
# 7 -1349381670501476147            23995799         0           65.95
#
#    CostPriceExclVAT BrandName ModelGroup ProductGroup ShopCategory
# ...

# %%
# Check the distribution of the 'Returned' column
print(filtered_df['Returned'].value_counts())
# Out:
# Returned
# 0    1210998
# 1      56896
# Name: count, dtype: int64

# %%
# Plot the distribution of ModelGroup by Returned
plt.figure(figsize=(10, 6))
sns.countplot(x='ModelGroup', hue='Returned', data=filtered_df)
plt.title('Return Distribution by ModelGroup')
plt.xlabel('ModelGroup')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Returned', loc='upper right')
plt.tight_layout()
plt.show()

# %%
# Plot the relationship between ProductGroup, Returned, and ModelGroup
plt.figure(figsize=(12, 8))
sns.countplot(x='ProductGroup', hue='Returned', data=df, palette='pastel')
plt.title('Return Distribution by ProductGroup')
plt.xlabel('ProductGroup')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Returned', loc='upper right')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 2
#       1 # Plot the relationship between ProductGroup, Returned, and ModelGroup
# ----> 2 plt.figure(figsize=(12, 8))
#       3 sns.countplot(x='ProductGroup', hue='Returned', data=df, palette='pastel')
#       4 plt.title('Return Distribution by ProductGroup')
#
# NameError: name 'plt' is not defined

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

# Check for duplicates
duplicates = df.duplicated()

# Count the total number of duplicates
total_duplicates = duplicates.sum()
print("Total duplicates:", total_duplicates)

# Remove duplicates
df_no_duplicates = df.drop_duplicates()

# Optionally, you can reset the index if needed
df_no_duplicates = df_no_duplicates.reset_index(drop=True)

# Optionally, you can overwrite the original DataFrame
# df = df.drop_duplicates().reset_index(drop=True)

# Print the shape of the DataFrame after removing duplicates
print("Shape after removing duplicates:", df_no_duplicates.shape)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df_no_duplicates.drop('Returned', axis=1), df_no_duplicates['Returned'], test_size=0.2, random_state=42)

# Define columns to be one-hot encoded
categorical_cols = ['BrandName', 'ModelGroup', 'ProductGroup', 'ShopCategory']

# Define preprocessing steps
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(handle_unknown='ignore'), categorical_cols)
    ],
    remainder='passthrough'
)

# Define the pipeline with preprocessing and scaling steps
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('scaler', StandardScaler(with_mean=False))  # Update with_mean=False here
])

# Fit and transform the data using the pipeline
X_train_scaled = pipeline.fit_transform(X_train)
X_test_scaled = pipeline.transform(X_test)
# Out:
# Total duplicates: 816535
# Shape after removing duplicates: (943354, 13)

# %%
# Check data types of each column
print(df.dtypes)

# Check for non-numeric columns
non_numeric_columns = df.select_dtypes(exclude=['int64', 'float64']).columns
print("Non-numeric columns:", non_numeric_columns)
# Out:
# Shop                           int64
# Order_Date_FK                  int64
# ProductCode                    int64
# OriginalSaleAmountInclVAT    float64
# CustomerID                     int64
# SaleDocumentNumber             int64
# Returned                       int64
# RevenueInclVAT               float64
# CostPriceExclVAT             float64
# BrandName                     object
# ModelGroup                    object
# ProductGroup                  object
# ShopCategory                  object
# dtype: object
# Non-numeric columns: Index(['BrandName', 'ModelGroup', 'ProductGroup', 'ShopCategory'], dtype='object')

# %%
# Check unique values in non-numeric columns
print("Unique values in BrandName:", df['BrandName'].unique())
print("Unique values in ModelGroup:", df['ModelGroup'].unique())
print("Unique values in ProductGroup:", df['ProductGroup'].unique())
print("Unique values in ShopCategory:", df['ShopCategory'].unique())
# Out:
# Unique values in BrandName: ['Brand_1' 'Brand_2' 'Brand_3' 'Brand_4' 'Brand_5' 'Brand_6' 'Brand_7'
#  'Brand_8' 'Brand_9' 'Brand_10' 'Brand_11' 'Brand_12' 'Brand_13'
#  'Brand_14' 'Brand_15' 'Brand_16' 'Brand_17' 'Brand_18' 'Brand_19'
#  'Brand_20' 'Brand_21' 'Brand_22' 'Brand_23' 'Brand_24' 'Brand_25'
#  'Brand_26' 'Brand_27' 'Brand_28' 'Brand_29' 'Brand_30' 'Brand_31'
#  'Brand_32' 'Brand_33' 'Brand_34' 'Brand_35' 'Brand_36' 'Brand_37'
#  'Brand_38' 'Brand_39' 'Brand_40' 'Brand_41' 'Brand_42' 'Brand_43'
#  'Brand_44' 'Brand_45' 'Brand_46' 'Brand_47' 'Brand_48' 'Brand_49'
#  'Brand_50' 'Brand_51' 'Brand_52' 'Brand_53' 'Brand_54' 'Brand_55'
#  'Brand_56' 'Brand_57' 'Brand_58' 'Brand_59' 'Brand_60' 'Brand_61'
#  'Brand_62' 'Brand_63' 'Brand_64' 'Brand_65' 'Brand_66' 'Brand_67'
#  'Brand_68' 'Brand_69' 'Brand_70' 'Brand_71' 'Brand_72' 'Brand_73'
#  'Brand_74' 'Brand_75' 'Brand_76' 'Brand_77' 'Brand_78' 'Brand_79'
#  'Brand_80' 'Brand_81' 'Brand_82' 'Brand_83' 'Brand_84' 'Brand_85'
# ...

# %%
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

# Initialize SMOTE object
smote = SMOTE(sampling_strategy='auto', random_state=42)

# Update pipeline to include SMOTE
pipeline = Pipeline([('smote', smote), ('model', LogisticRegression(random_state=42))])

# Fit pipeline to training data
pipeline.fit(X_train, y_train)

# Make predictions
y_pred = pipeline.predict(X_test)

# %%
X_train.shape
# Out:
# (1407911, 685)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("ROC AUC Score:", roc_auc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 3
#       1 from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
# ----> 3 accuracy = accuracy_score(y_test, y_pred)
#       4 precision = precision_score(y_test, y_pred)
#       5 recall = recall_score(y_test, y_pred)
#
# NameError: name 'y_pred' is not defined

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(pipeline, X, y, cv=5)
print("Cross-Validation Scores:", cv_scores)
print("Mean Cross-Validation Score:", cv_scores.mean())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 from sklearn.model_selection import cross_val_score
# ----> 3 cv_scores = cross_val_score(pipeline, X, y, cv=5)
#       4 print("Cross-Validation Scores:", cv_scores)
#       5 print("Mean Cross-Validation Score:", cv_scores.mean())
#
# File c:\Users\jyoti\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
# ...

# %%
# Check for duplicates
duplicates = df.duplicated()

# Count the total number of duplicates
total_duplicates = duplicates.sum()
print("Total duplicates:", total_duplicates)

# Remove duplicates
df_no_duplicates = df.drop_duplicates()

# Optionally, you can reset the index if needed
df_no_duplicates = df_no_duplicates.reset_index(drop=True)

# Optionally, you can overwrite the original DataFrame
# df = df.drop_duplicates().reset_index(drop=True)

# Print the shape of the DataFrame after removing duplicates
print("Shape after removing duplicates:", df_no_duplicates.shape)
# Out:
# Total duplicates: 816535
# Shape after removing duplicates: (943354, 13)

# %%
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Load the dataset
df = pd.read_csv("your_dataset.csv")

# Split the data into features (X) and target (y)
X = df_no_duplicates[['BrandName', 'ModelGroup', 'ProductGroup', 'ShopCategory']]
y = df_no_duplicates['Returned']

# One-hot encode categorical features
encoder = OneHotEncoder(drop='first')
X_encoded = encoder.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Initialize SMOTE object
smote = SMOTE(sampling_strategy='auto', random_state=42)

# Update pipeline to include SMOTE
pipeline = Pipeline([('smote', smote), ('model', LogisticRegression(random_state=42))])

# Fit pipeline to training data
pipeline.fit(X_train, y_train)

# Make predictions
y_pred = pipeline.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("ROC AUC Score:", roc_auc)

import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve

# Calculate precision and recall
precision, recall, _ = precision_recall_curve(y_test, y_pred)

# Plot precision-recall curve
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, marker='.')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.grid(True)
plt.show()
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Compute ROC curve and ROC area for the predictions
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# Accuracy: 0.7902380334020597
# Precision: 0.14378977138816876
# Recall: 0.65265297389816
# F1 Score: 0.23565993278998804
# ROC AUC Score: 0.7250316167985695

# %%
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import pandas as pd

# Assuming you have loaded your dataset and removed duplicates as df_no_duplicates
# Check for duplicates
duplicates = df.duplicated()

# Count the total number of duplicates
total_duplicates = duplicates.sum()
print("Total duplicates:", total_duplicates)

# Remove duplicates
df_no_duplicates = df.drop_duplicates()

# Optionally, you can reset the index if needed
df_no_duplicates = df_no_duplicates.reset_index(drop=True)

# Optionally, you can overwrite the original DataFrame
# df = df.drop_duplicates().reset_index(drop=True)

# Print the shape of the DataFrame after removing duplicates
print("Shape after removing duplicates:", df_no_duplicates.shape)

# Split the data into features (X) and target (y)
X = df_no_duplicates[['BrandName', 'ModelGroup', 'ProductGroup', 'ShopCategory']]
y = df_no_duplicates['Returned']

# One-hot encode categorical features
encoder = OneHotEncoder(drop='first')
X_encoded = encoder.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Initialize SMOTE object
smote = SMOTE(sampling_strategy='auto', random_state=42)

# Define the pipeline
pipeline = Pipeline([('smote', smote), ('model', GradientBoostingClassifier(random_state=42))])

# Fit pipeline to training data
pipeline.fit(X_train, y_train)

# Make predictions
y_pred = pipeline.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("ROC AUC Score:", roc_auc)
# Out:
# Total duplicates: 816535
# Shape after removing duplicates: (943354, 13)
# Accuracy: 0.8385655453143303
# Precision: 0.1723881060276864
# Recall: 0.594137783483098
# F1 Score: 0.2672376461531059
# ROC AUC Score: 0.7227226004124946

# %% [markdown]
# Using Random Forest

# %%
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import OneHotEncoder
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import time

# Assuming you have loaded your dataset and removed duplicates as df_no_duplicates
# Check for duplicates
duplicates = df.duplicated()
total_duplicates = duplicates.sum()
print("Total duplicates:", total_duplicates)

# Remove duplicates
df_no_duplicates = df.drop_duplicates().reset_index(drop=True)
print("Shape after removing duplicates:", df_no_duplicates.shape)

# Split the data into features (X) and target (y)
X = df_no_duplicates[['BrandName', 'ModelGroup', 'ProductGroup', 'ShopCategory']]
y = df_no_duplicates['Returned']

# One-hot encode categorical features
encoder = OneHotEncoder(drop='first')
X_encoded = encoder.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Initialize SMOTE object
smote = SMOTE(sampling_strategy='auto', random_state=42)

# Define the pipeline with Decision Tree classifier
pipeline_dt = Pipeline([('smote', smote), ('model', DecisionTreeClassifier(random_state=42))])

# Define the hyperparameter grid for Decision Tree
param_grid_dt = {
    'model__max_depth': [None, 5],
    'model__min_samples_split': [2, 5]
}

# Initialize RandomizedSearchCV with fewer iterations
grid_search_dt = RandomizedSearchCV(pipeline_dt, param_grid_dt, cv=5, scoring='accuracy', n_iter=3, random_state=42)

# Start timer
start_time = time.time()

# Fit RandomizedSearchCV to training data
grid_search_dt.fit(X_train, y_train)

# End timer
end_time = time.time()

# Compute elapsed time
elapsed_time = end_time - start_time
print("Elapsed Time (seconds):", elapsed_time)

# Get the best hyperparameters and model
best_params_dt = grid_search_dt.best_params_
best_model_dt = grid_search_dt.best_estimator_

# Make predictions
y_pred_dt = best_model_dt.predict(X_test)

# Evaluate the model
accuracy_dt = accuracy_score(y_test, y_pred_dt)
precision_dt = precision_score(y_test, y_pred_dt)
recall_dt = recall_score(y_test, y_pred_dt)
f1_dt = f1_score(y_test, y_pred_dt)
roc_auc_dt = roc_auc_score(y_test, y_pred_dt)

print("Best Hyperparameters (Decision Tree):", best_params_dt)
print("Accuracy (Decision Tree):", accuracy_dt)
print("Precision (Decision Tree):", precision_dt)
print("Recall (Decision Tree):", recall_dt)
print("F1 Score (Decision Tree):", f1_dt)
print("ROC AUC Score (Decision Tree):", roc_auc_dt)
# Out:
# Total duplicates: 816535
# Shape after removing duplicates: (943354, 13)
# Elapsed Time (seconds): 1310.7393412590027
# Best Hyperparameters (Decision Tree): {'model__min_samples_split': 5, 'model__max_depth': 5}
# Accuracy (Decision Tree): 0.8537242077478786
# Precision (Decision Tree): 0.1841030256871841
# Recall (Decision Tree): 0.5688917415489945
# F1 Score (Decision Tree): 0.27818172307370403
# ROC AUC Score (Decision Tree): 0.7187320471155132

# %%
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import OneHotEncoder
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import time

# Assuming you have loaded your dataset and removed duplicates as df_no_duplicates
# Check for duplicates
duplicates = df.duplicated()
total_duplicates = duplicates.sum()
print("Total duplicates:", total_duplicates)

# Remove duplicates
df_no_duplicates = df.drop_duplicates().reset_index(drop=True)
print("Shape after removing duplicates:", df_no_duplicates.shape)

# Split the data into features (X) and target (y)
X = df_no_duplicates[['BrandName', 'ModelGroup', 'ProductGroup', 'ShopCategory']]
y = df_no_duplicates['Returned']

# One-hot encode categorical features
encoder = OneHotEncoder(drop='first')
X_encoded = encoder.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Initialize SMOTE object
smote = SMOTE(sampling_strategy='auto', random_state=42)

# Define the pipeline with XGBoost classifier
pipeline_xgb = Pipeline([('smote', smote), ('model', XGBClassifier(random_state=42))])

# Define the hyperparameter grid for XGBoost
param_grid_xgb = {
    'model__max_depth': [3, 6],
    'model__learning_rate': [0.1, 0.3],
    'model__n_estimators': [100, 200],
}

# Initialize RandomizedSearchCV with fewer iterations
grid_search_xgb = RandomizedSearchCV(pipeline_xgb, param_grid_xgb, cv=5, scoring='accuracy', n_iter=3, random_state=42)

# Start timer
start_time = time.time()

# Fit RandomizedSearchCV to training data
grid_search_xgb.fit(X_train, y_train)

# End timer
end_time = time.time()

# Compute elapsed time
elapsed_time = end_time - start_time
print("Elapsed Time (seconds):", elapsed_time)

# Get the best hyperparameters and model
best_params_xgb = grid_search_xgb.best_params_
best_model_xgb = grid_search_xgb.best_estimator_

# Make predictions
y_pred_xgb = best_model_xgb.predict(X_test)

# Evaluate the model
accuracy_xgb = accuracy_score(y_test, y_pred_xgb)
precision_xgb = precision_score(y_test, y_pred_xgb)
recall_xgb = recall_score(y_test, y_pred_xgb)
f1_xgb = f1_score(y_test, y_pred_xgb)
roc_auc_xgb = roc_auc_score(y_test, y_pred_xgb)

print("Best Hyperparameters (XGBoost):", best_params_xgb)
print("Accuracy (XGBoost):", accuracy_xgb)
print("Precision (XGBoost):", precision_xgb)
print("Recall (XGBoost):", recall_xgb)
print("F1 Score (XGBoost):", f1_xgb)
print("ROC AUC Score (XGBoost):", roc_auc_xgb)
# Out:
# Total duplicates: 816535
# Shape after removing duplicates: (943354, 13)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 51
#      48 start_time = time.time()
#      50 # Fit RandomizedSearchCV to training data
# ---> 51 grid_search_xgb.fit(X_train, y_train)
#      53 # End timer
#      54 end_time = time.time()
#
# File c:\Users\jyoti\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from imblearn.over_sampling import SMOTE

# Load the dataset
df = pd.read_csv("your_dataset.csv")
# Check for duplicates
duplicates = df.duplicated()
total_duplicates = duplicates.sum()
print("Total duplicates:", total_duplicates)

# Remove duplicates
df_no_duplicates = df.drop_duplicates().reset_index(drop=True)
print("Shape after removing duplicates:", df_no_duplicates.shape)

# Split the data into features (X) and target (y)
X = df_no_duplicates[['BrandName', 'ModelGroup', 'ProductGroup', 'ShopCategory']]
y = df_no_duplicates['Returned']

# One-hot encode categorical features
encoder = OneHotEncoder(drop='first')
X_encoded = encoder.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)


# Scale features
scaler = StandardScaler(with_mean=False)  # Set with_mean=False for sparse matrices
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Apply SMOTE to handle class imbalance
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_scaled, y_train)

# Train models
models = {
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Random Forest': RandomForestClassifier(n_estimators=100, random_state=42),
    'Naive Bayes': GaussianNB()
}
for name, model in models.items():
    model.fit(X_train_resampled, y_train_resampled)
    y_pred = model.predict(X_test_scaled)
    print(f"\n{name}:")
    print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
    print(f"Precision: {precision_score(y_test, y_pred)}")
    print(f"Recall: {recall_score(y_test, y_pred)}")
    print(f"F1-score: {f1_score(y_test, y_pred)}")
    print(f"Confusion Matrix:\n{confusion_matrix(y_test, y_pred)}")

    # Save confusion matrix plot
    plt.figure()
    sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
    plt.title(f'Confusion Matrix - {name}')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.savefig(f'confusion_matrix_{name.replace(" ", "_")}.png')
# Out:
# Total duplicates: 816535
# Shape after removing duplicates: (943354, 13)
#
# Decision Tree:
# Accuracy: 0.7896550079238462
# Precision: 0.1434850051706308
# Recall: 0.6530808729139923
# F1-score: 0.2352782488053029
# Confusion Matrix:
# [[142880  36443]
#  [  3243   6105]]
#
# Random Forest:
# Accuracy: 0.7902380334020597
# Precision: 0.14378977138816876
# Recall: 0.65265297389816
# F1-score: 0.23565993278998804
# Confusion Matrix:
# [[142994  36329]
#  [  3247   6101]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 51
#      45 models = {
#      46     'Decision Tree': DecisionTreeClassifier(random_state=42),
#      47     'Random Forest': RandomForestClassifier(n_estimators=100, random_state=42),
#      48     'Naive Bayes': GaussianNB()
#      49 }
#      50 for name, model in models.items():
# ---> 51     model.fit(X_train_resampled, y_train_resampled)
# ...
